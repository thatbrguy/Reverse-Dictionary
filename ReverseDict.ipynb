# %%
from collections import Counter, OrderedDict
import numpy as np
import string
import re
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout, Embedding
from keras.layers import LSTM, CuDNNGRU
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
from keras.preprocessing.sequence import pad_sequences
# Out:
# /home/br7/anaconda3/envs/tf/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def data():
    
    punc_table = str.maketrans({key: None for key in string.punctuation})
    sentences = []
    targets = []
    with open('dataset.txt', 'r') as filee:
        for i, line in enumerate(filee):
            words = line.strip('\n').split('\t')
            word = words[0]
            definitions = words[1].split('; ')
            for definition in definitions:
                definition = re.sub("[\(\[].*?[\)\]]", "", definition).replace('  ', ' ')
                if definition[-1] == ' ':
                    definition = definition[:-1]

                temp_word_list = definition.translate(punc_table).lower().split(' ')
                temp_word_list = list(filter(None, temp_word_list))
                sentences.append(['<start>'] + temp_word_list + ['<end>'])
                targets.append(word)
                
    words = [word for word_sublist in sentences for word in word_sublist] 
    inf = float('inf')
    frequency_dict = OrderedDict({'<end>': inf, '<start>': inf})
    words_frequency_dict = sorted(Counter(words).most_common(None), key=lambda x:x[1], reverse=True)
    defs_frequency_dict = sorted(Counter(targets).most_common(None), key=lambda x:x[1], reverse=True)

    frequency_dict.update(words_frequency_dict)
    frequency_dict.update(defs_frequency_dict)
    frequency_dict.move_to_end('<start>', last=False)

    word2idx = OrderedDict([(item[0], i) for i,item in enumerate(frequency_dict.items())])
    idx2word = dict(zip(word2idx.values(), word2idx.keys()))
    
    return sentences, targets, word2idx, idx2word

# %%
def sent2idx(sentences, targets, word2idx):
    s = []
    for sentence in sentences:
        s.append([word2idx[word] for word in sentence])
    t = []
    for word in targets:
        t.append(word2idx[word])
    return s, t

# %%
SEQUENCE_LENGTH = 55
BATCH_SIZE = 100
EPOCHS = 100

sentences, targets, word2idx, idx2word = data()
sentences, targets = sent2idx(sentences, targets, word2idx)
targets = np_utils.to_categorical(targets)
batches = len(sentences) // BATCH_SIZE
print('Sentences:',len(sentences))
print('Vocab Size:',len(word2idx))
print('Batches:',batches)
# Out:
# Sentences: 3281
# Vocab Size: 5817
# Batches: 32

# %%
model = Sequential()
model.add(Embedding(input_dim = len(word2idx), output_dim = 512))
model.add(CuDNNGRU(512, return_sequences = True))
model.add(Dropout(0.2))
model.add(CuDNNGRU(512))
model.add(Dropout(0.2))
model.add(Dense(len(word2idx), activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam')
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 512)         2978304
# _________________________________________________________________
# cu_dnngru_1 (CuDNNGRU)       (None, None, 512)         1575936
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 512)         0
# _________________________________________________________________
# cu_dnngru_2 (CuDNNGRU)       (None, 512)               1575936
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5817)              2984121
# =================================================================
# Total params: 9,114,297
# Trainable params: 9,114,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
filepath="weights-improvement-{epoch:02d}-{loss:.4f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [checkpoint]

model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# %%
# Use the other generator
'''
def generator2(inputs, targets, batch_size):
    
    batches = len(inputs) // batch_size
    for i in range(batches):
        if i == batches-1:
            batch_inputs = pad_sequences(inputs[i*batch_size:])
            batch_targets = targets[i*batch_size:]
        else:
            batch_inputs = pad_sequences(inputs[i*batch_size: (i+1)*batch_size])
            batch_targets = targets[i*batch_size: (i+1)*batch_size]
            
        yield batch_inputs, batch_targets
'''

# %%
def generator(inputs, targets, batch_size):
    inputs = np.array(inputs)
    while True:
        perm = np.random.permutation(len(inputs))[:batch_size]
        batch_inputs = pad_sequences(inputs[perm])
        batch_targets = targets[perm]
        
        yield batch_inputs, batch_targets

# %%
input_ = np.array(targets)
model.fit_generator(generator = generator(sentences, targets, BATCH_SIZE), epochs = EPOCHS, samples_per_epoch = batches, callbacks=callbacks_list)
# Out:
# /home/br7/anaconda3/envs/tf/lib/python3.5/site-packages/ipykernel_launcher.py:2: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(callbacks=[<keras.ca..., epochs=100, steps_per_epoch=32, generator=<generator...)`
# Epoch 1/100
# 32/32 [==============================] - 7s 221ms/step - loss: 8.5652
#
# Epoch 00001: loss improved from inf to 8.56523, saving model to weights-improvement-01-8.5652.hdf5
# Epoch 2/100
# 32/32 [==============================] - 6s 188ms/step - loss: 8.1611
#
# Epoch 00002: loss improved from 8.56523 to 8.16107, saving model to weights-improvement-02-8.1611.hdf5
# Epoch 3/100
# 32/32 [==============================] - 6s 191ms/step - loss: 7.8235
#
# Epoch 00003: loss improved from 8.16107 to 7.82354, saving model to weights-improvement-03-7.8235.hdf5
# Epoch 4/100
# 32/32 [==============================] - 6s 189ms/step - loss: 7.3506
#
# Epoch 00004: loss improved from 7.82354 to 7.35065, saving model to weights-improvement-04-7.3506.hdf5
# Epoch 5/100
# 32/32 [==============================] - 6s 187ms/step - loss: 6.7999
#
# Epoch 00005: loss improved from 7.35065 to 6.79990, saving model to weights-improvement-05-6.7999.hdf5
# Epoch 6/100
# 32/32 [==============================] - 6s 194ms/step - loss: 6.2566
#
# Epoch 00006: loss improved from 6.79990 to 6.25660, saving model to weights-improvement-06-6.2566.hdf5
# Epoch 7/100
# 32/32 [==============================] - 6s 199ms/step - loss: 5.5554
#
# Epoch 00007: loss improved from 6.25660 to 5.55539, saving model to weights-improvement-07-5.5554.hdf5
# Epoch 8/100
# 32/32 [==============================] - 6s 194ms/step - loss: 4.8298
#
# Epoch 00008: loss improved from 5.55539 to 4.82983, saving model to weights-improvement-08-4.8298.hdf5
# Epoch 9/100
# 32/32 [==============================] - 6s 199ms/step - loss: 4.1828
#
# Epoch 00009: loss improved from 4.82983 to 4.18283, saving model to weights-improvement-09-4.1828.hdf5
# Epoch 10/100
# 32/32 [==============================] - 6s 192ms/step - loss: 3.4801
#
# Epoch 00010: loss improved from 4.18283 to 3.48007, saving model to weights-improvement-10-3.4801.hdf5
# Epoch 11/100
# 32/32 [==============================] - 6s 198ms/step - loss: 2.9112
#
# Epoch 00011: loss improved from 3.48007 to 2.91122, saving model to weights-improvement-11-2.9112.hdf5
# Epoch 12/100
# 32/32 [==============================] - 6s 200ms/step - loss: 2.3397
#
# Epoch 00012: loss improved from 2.91122 to 2.33972, saving model to weights-improvement-12-2.3397.hdf5
# Epoch 13/100
# 32/32 [==============================] - 6s 199ms/step - loss: 1.9270
#
# Epoch 00013: loss improved from 2.33972 to 1.92700, saving model to weights-improvement-13-1.9270.hdf5
# Epoch 14/100
# 32/32 [==============================] - 6s 197ms/step - loss: 1.4957
#
# Epoch 00014: loss improved from 1.92700 to 1.49575, saving model to weights-improvement-14-1.4957.hdf5
# Epoch 15/100
# 32/32 [==============================] - 6s 198ms/step - loss: 1.2277
#
# Epoch 00015: loss improved from 1.49575 to 1.22767, saving model to weights-improvement-15-1.2277.hdf5
# Epoch 16/100
# 32/32 [==============================] - 6s 188ms/step - loss: 0.9746
#
# Epoch 00016: loss improved from 1.22767 to 0.97457, saving model to weights-improvement-16-0.9746.hdf5
# Epoch 17/100
# 32/32 [==============================] - 6s 193ms/step - loss: 0.7945
#
# Epoch 00017: loss improved from 0.97457 to 0.79446, saving model to weights-improvement-17-0.7945.hdf5
# Epoch 18/100
# 32/32 [==============================] - 6s 192ms/step - loss: 0.6726
#
# Epoch 00018: loss improved from 0.79446 to 0.67258, saving model to weights-improvement-18-0.6726.hdf5
# Epoch 19/100
# 32/32 [==============================] - 7s 203ms/step - loss: 0.5432
#
# Epoch 00019: loss improved from 0.67258 to 0.54321, saving model to weights-improvement-19-0.5432.hdf5
# Epoch 20/100
# 32/32 [==============================] - 6s 192ms/step - loss: 0.4632
#
# Epoch 00020: loss improved from 0.54321 to 0.46315, saving model to weights-improvement-20-0.4632.hdf5
# Epoch 21/100
# 32/32 [==============================] - 6s 196ms/step - loss: 0.3697
#
# Epoch 00021: loss improved from 0.46315 to 0.36967, saving model to weights-improvement-21-0.3697.hdf5
# Epoch 22/100
# 32/32 [==============================] - 6s 197ms/step - loss: 0.3133
#
# Epoch 00022: loss improved from 0.36967 to 0.31327, saving model to weights-improvement-22-0.3133.hdf5
# Epoch 23/100
# 32/32 [==============================] - 6s 190ms/step - loss: 0.2811
#
# Epoch 00023: loss improved from 0.31327 to 0.28109, saving model to weights-improvement-23-0.2811.hdf5
# Epoch 24/100
# 32/32 [==============================] - 6s 198ms/step - loss: 0.2661
#
# Epoch 00024: loss improved from 0.28109 to 0.26607, saving model to weights-improvement-24-0.2661.hdf5
# Epoch 25/100
# 32/32 [==============================] - 6s 195ms/step - loss: 0.2152
#
# Epoch 00025: loss improved from 0.26607 to 0.21521, saving model to weights-improvement-25-0.2152.hdf5
# Epoch 26/100
# 32/32 [==============================] - 6s 199ms/step - loss: 0.2084
#
# Epoch 00026: loss improved from 0.21521 to 0.20836, saving model to weights-improvement-26-0.2084.hdf5
# Epoch 27/100
# 32/32 [==============================] - 7s 207ms/step - loss: 0.1765
#
# Epoch 00027: loss improved from 0.20836 to 0.17649, saving model to weights-improvement-27-0.1765.hdf5
# Epoch 28/100
# 32/32 [==============================] - 6s 198ms/step - loss: 0.1519
#
# Epoch 00028: loss improved from 0.17649 to 0.15189, saving model to weights-improvement-28-0.1519.hdf5
# Epoch 29/100
# 32/32 [==============================] - 6s 193ms/step - loss: 0.1490
#
# Epoch 00029: loss improved from 0.15189 to 0.14902, saving model to weights-improvement-29-0.1490.hdf5
# Epoch 30/100
# 32/32 [==============================] - 6s 203ms/step - loss: 0.1267
#
# Epoch 00030: loss improved from 0.14902 to 0.12671, saving model to weights-improvement-30-0.1267.hdf5
# Epoch 31/100
# 32/32 [==============================] - 7s 210ms/step - loss: 0.1180
#
# Epoch 00031: loss improved from 0.12671 to 0.11803, saving model to weights-improvement-31-0.1180.hdf5
# Epoch 32/100
# 32/32 [==============================] - 6s 197ms/step - loss: 0.1128
#
# Epoch 00032: loss improved from 0.11803 to 0.11278, saving model to weights-improvement-32-0.1128.hdf5
# Epoch 33/100
# 32/32 [==============================] - 6s 201ms/step - loss: 0.1104
#
# Epoch 00033: loss improved from 0.11278 to 0.11042, saving model to weights-improvement-33-0.1104.hdf5
# Epoch 34/100
# 32/32 [==============================] - 6s 197ms/step - loss: 0.0998
#
# Epoch 00034: loss improved from 0.11042 to 0.09979, saving model to weights-improvement-34-0.0998.hdf5
# Epoch 35/100
# 32/32 [==============================] - 6s 200ms/step - loss: 0.0967
#
# Epoch 00035: loss improved from 0.09979 to 0.09674, saving model to weights-improvement-35-0.0967.hdf5
# Epoch 36/100
# 32/32 [==============================] - 6s 199ms/step - loss: 0.0773
#
# Epoch 00036: loss improved from 0.09674 to 0.07731, saving model to weights-improvement-36-0.0773.hdf5
# Epoch 37/100
# 32/32 [==============================] - 6s 197ms/step - loss: 0.0837
#
# Epoch 00037: loss did not improve
# Epoch 38/100
# 32/32 [==============================] - 6s 199ms/step - loss: 0.0688
#
# Epoch 00038: loss improved from 0.07731 to 0.06878, saving model to weights-improvement-38-0.0688.hdf5
# Epoch 39/100
# 32/32 [==============================] - 6s 198ms/step - loss: 0.0811
#
# Epoch 00039: loss did not improve
# Epoch 40/100
# 32/32 [==============================] - 6s 191ms/step - loss: 0.0707
#
# Epoch 00040: loss did not improve
# Epoch 41/100
# 32/32 [==============================] - 6s 193ms/step - loss: 0.0716
#
# Epoch 00041: loss did not improve
# Epoch 42/100
# 32/32 [==============================] - 6s 194ms/step - loss: 0.0620
#
# Epoch 00042: loss improved from 0.06878 to 0.06195, saving model to weights-improvement-42-0.0620.hdf5
# Epoch 43/100
# 32/32 [==============================] - 6s 200ms/step - loss: 0.0684
#
# Epoch 00043: loss did not improve
# Epoch 44/100
# 32/32 [==============================] - 6s 193ms/step - loss: 0.0644
#
# Epoch 00044: loss did not improve
# Epoch 45/100
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0663
#
# Epoch 00045: loss did not improve
# Epoch 46/100
# 32/32 [==============================] - 6s 191ms/step - loss: 0.0613
#
# Epoch 00046: loss improved from 0.06195 to 0.06127, saving model to weights-improvement-46-0.0613.hdf5
# Epoch 47/100
# 32/32 [==============================] - 6s 189ms/step - loss: 0.0679
#
# Epoch 00047: loss did not improve
# Epoch 48/100
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0587
#
# Epoch 00048: loss improved from 0.06127 to 0.05871, saving model to weights-improvement-48-0.0587.hdf5
# Epoch 49/100
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0596
#
# Epoch 00049: loss did not improve
# Epoch 50/100
# 32/32 [==============================] - 6s 189ms/step - loss: 0.0534
#
# Epoch 00050: loss improved from 0.05871 to 0.05338, saving model to weights-improvement-50-0.0534.hdf5
# Epoch 51/100
# 32/32 [==============================] - 6s 190ms/step - loss: 0.0616
#
# Epoch 00051: loss did not improve
# Epoch 52/100
# 32/32 [==============================] - 6s 197ms/step - loss: 0.0547
#
# Epoch 00052: loss did not improve
# Epoch 53/100
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0597
#
# Epoch 00053: loss did not improve
# Epoch 54/100
# 32/32 [==============================] - 6s 191ms/step - loss: 0.0702
#
# Epoch 00054: loss did not improve
# Epoch 55/100
# 32/32 [==============================] - 6s 183ms/step - loss: 0.0550
#
# Epoch 00055: loss did not improve
# Epoch 56/100
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0502
#
# Epoch 00056: loss improved from 0.05338 to 0.05016, saving model to weights-improvement-56-0.0502.hdf5
# Epoch 57/100
# 32/32 [==============================] - 6s 184ms/step - loss: 0.0556
#
# Epoch 00057: loss did not improve
# Epoch 58/100
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0479
#
# Epoch 00058: loss improved from 0.05016 to 0.04785, saving model to weights-improvement-58-0.0479.hdf5
# Epoch 59/100
# 32/32 [==============================] - 6s 194ms/step - loss: 0.0474
#
# Epoch 00059: loss improved from 0.04785 to 0.04740, saving model to weights-improvement-59-0.0474.hdf5
# Epoch 60/100
# 32/32 [==============================] - 6s 198ms/step - loss: 0.0489
#
# Epoch 00060: loss did not improve
# Epoch 61/100
# 32/32 [==============================] - 6s 199ms/step - loss: 0.0355
#
# Epoch 00061: loss improved from 0.04740 to 0.03546, saving model to weights-improvement-61-0.0355.hdf5
# Epoch 62/100
# 32/32 [==============================] - 6s 194ms/step - loss: 0.0503
#
# Epoch 00062: loss did not improve
# Epoch 63/100
# 32/32 [==============================] - 6s 192ms/step - loss: 0.0502
#
# Epoch 00063: loss did not improve
# Epoch 64/100
# 32/32 [==============================] - 6s 190ms/step - loss: 0.0448
#
# Epoch 00064: loss did not improve
# Epoch 65/100
# 32/32 [==============================] - 6s 186ms/step - loss: 0.0484
#
# Epoch 00065: loss did not improve
# Epoch 66/100
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0504
#
# Epoch 00066: loss did not improve
# Epoch 67/100
# 32/32 [==============================] - 7s 208ms/step - loss: 0.0427
#
# Epoch 00067: loss did not improve
# Epoch 68/100
# 32/32 [==============================] - 6s 199ms/step - loss: 0.0494
#
# Epoch 00068: loss did not improve
# Epoch 69/100
# 32/32 [==============================] - 6s 198ms/step - loss: 0.0394
#
# Epoch 00069: loss did not improve
# Epoch 70/100
# 32/32 [==============================] - 6s 190ms/step - loss: 0.0529
#
# Epoch 00070: loss did not improve
# Epoch 71/100
# 32/32 [==============================] - 6s 195ms/step - loss: 0.0438
#
# Epoch 00071: loss did not improve
# Epoch 72/100
# 32/32 [==============================] - 6s 193ms/step - loss: 0.0420
#
# Epoch 00072: loss did not improve
# Epoch 73/100
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0463
#
# Epoch 00073: loss did not improve
# Epoch 74/100
# 32/32 [==============================] - 6s 189ms/step - loss: 0.0621
#
# Epoch 00074: loss did not improve
# Epoch 75/100
# 32/32 [==============================] - 6s 183ms/step - loss: 0.0562
#
# Epoch 00075: loss did not improve
# Epoch 76/100
# 32/32 [==============================] - 6s 194ms/step - loss: 0.0559
#
# Epoch 00076: loss did not improve
# Epoch 77/100
# 32/32 [==============================] - 6s 201ms/step - loss: 0.0449
#
# Epoch 00077: loss did not improve
# Epoch 78/100
# 32/32 [==============================] - 6s 197ms/step - loss: 0.0451
#
# Epoch 00078: loss did not improve
# Epoch 79/100
# 32/32 [==============================] - 6s 189ms/step - loss: 0.0570
#
# Epoch 00079: loss did not improve
# Epoch 80/100
# 32/32 [==============================] - 6s 182ms/step - loss: 0.0554
#
# Epoch 00080: loss did not improve
# Epoch 81/100
# 32/32 [==============================] - 6s 187ms/step - loss: 0.0702
#
# Epoch 00081: loss did not improve
# Epoch 82/100
# 32/32 [==============================] - 6s 181ms/step - loss: 0.0528
#
# Epoch 00082: loss did not improve
# Epoch 83/100
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0590
#
# Epoch 00083: loss did not improve
# Epoch 84/100
# 32/32 [==============================] - 6s 185ms/step - loss: 0.0580
#
# Epoch 00084: loss did not improve
# Epoch 85/100
# 32/32 [==============================] - 6s 179ms/step - loss: 0.0659
#
# Epoch 00085: loss did not improve
# Epoch 86/100
# 32/32 [==============================] - 6s 182ms/step - loss: 0.0895
#
# Epoch 00086: loss did not improve
# Epoch 87/100
# 32/32 [==============================] - 6s 177ms/step - loss: 0.0912
#
# Epoch 00087: loss did not improve
# Epoch 88/100
# 32/32 [==============================] - 6s 182ms/step - loss: 0.1174
#
# Epoch 00088: loss did not improve
# Epoch 89/100
# 32/32 [==============================] - 6s 186ms/step - loss: 0.1349
#
# Epoch 00089: loss did not improve
# Epoch 90/100
# 32/32 [==============================] - 6s 180ms/step - loss: 0.1441
#
# Epoch 00090: loss did not improve
# Epoch 91/100
# 32/32 [==============================] - 6s 188ms/step - loss: 0.1462
#
# Epoch 00091: loss did not improve
# Epoch 92/100
# 32/32 [==============================] - 6s 191ms/step - loss: 0.1355
#
# Epoch 00092: loss did not improve
# Epoch 93/100
# 32/32 [==============================] - 6s 192ms/step - loss: 0.1024
#
# Epoch 00093: loss did not improve
# Epoch 94/100
# 32/32 [==============================] - 6s 196ms/step - loss: 0.1064
#
# Epoch 00094: loss did not improve
# Epoch 95/100
# 32/32 [==============================] - 6s 191ms/step - loss: 0.0890
#
# Epoch 00095: loss did not improve
# Epoch 96/100
# 32/32 [==============================] - 6s 191ms/step - loss: 0.0652
#
# Epoch 00096: loss did not improve
# Epoch 97/100
# 32/32 [==============================] - 6s 196ms/step - loss: 0.0705
#
# Epoch 00097: loss did not improve
# Epoch 98/100
# 32/32 [==============================] - 6s 195ms/step - loss: 0.0548
#
# Epoch 00098: loss did not improve
# Epoch 99/100
# 32/32 [==============================] - 6s 188ms/step - loss: 0.0642
#
# Epoch 00099: loss did not improve
# Epoch 100/100
# 32/32 [==============================] - 6s 200ms/step - loss: 0.0463
#
# Epoch 00100: loss did not improve

# %%
model.save('weights.h5')

# %%
definition = 'examine closely at something'
words = definition.split(' ')
idxs = []
for word in words:
    idxs.append(word2idx[word])

idxs = np.array([0] + idxs + [1]).reshape((1,len(idxs) + 2))
prediction = model.predict(idxs, verbose=0)
index = np.argmax(prediction)
meaning = idx2word[index]

# %%
meaning
# Out:
# 'must'
